# %%
import os
os.chdir('/public/home/zhanghn/VScodeProject/Python/Jupyter/ResNet/ResNet18')
from inference import predict

# %%
predict("models/resnet18.pth","test_data/num_5.jpg")
# Out:
# Predict value is  5
